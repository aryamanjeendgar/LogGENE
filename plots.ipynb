# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
A= np.load("/home/aryamanj/Downloads/D-GEX_first/ls_a.npy")
B= np.load("/home/aryamanj/Downloads/D-GEX_first/ls_b.npy")
C= np.load("/home/aryamanj/Downloads/D-GEX_first/ls_c.npy")
D= np.load("/home/aryamanj/Downloads/D-GEX_first/ls_d.npy")
E= np.load("/home/aryamanj/Downloads/D-GEX_first/ls_e.npy")
F= np.load("/home/aryamanj/Downloads/D-GEX_first/ls_f.npy")
G= np.load("/home/aryamanj/Downloads/D-GEX_first/ls_g.npy")
H= np.load("/home/aryamanj/Downloads/D-GEX_first/ls_h.npy")
I= np.load("/home/aryamanj/Downloads/D-GEX_first/ls_i.npy")
J= np.load("/home/aryamanj/Downloads/D-GEX_first/ls_j.npy")

# %%
loss_CLR= np.load("/home/aryamanj/Downloads/D-GEX_second/lossList_CLR_S.npy")
val_CLR= np.load("/home/aryamanj/Downloads/D-GEX_second/valList_CLR_S.npy")
loss_adaH= np.load("/home/aryamanj/Downloads/D-GEX_second/lossList_adaH_S.npy")
val_adaH= np.load("/home/aryamanj/Downloads/D-GEX_second/valList_adaH_S.npy")
loss_LR= np.load("/home/aryamanj/Downloads/D-GEX_second/lossList_LR_S.npy")
val_LR= np.load("/home/aryamanj/Downloads/D-GEX_second/valList_LR_S.npy")
loss_CLR_MAE= np.load("/home/aryamanj/Downloads/D-GEX_second/lossList_CLR_S_MAE.npy")
val_CLR_MAE= np.load("/home/aryamanj/Downloads/D-GEX_second/valList_CLR_S_MAE.npy")
loss_LR_MAE= np.load("/home/aryamanj/Downloads/D-GEX_second/lossList_LR_S_MAE.npy")
val_LR_MAE= np.load("/home/aryamanj/Downloads/D-GEX_second/valList_LR_S_MAE.npy")

# %%
N_EPOCHS= 100
# plt.plot(range(N_EPOCHS), A[0:100], label= "small-ConstLR")
# plt.plot(range(N_EPOCHS), B[0:100], label= "medium-ConstLR")
# plt.plot(range(N_EPOCHS), C[0:100], label= "large-ConstLR")
# plt.plot(range(N_EPOCHS), D[0:100], label= "wideM-ConstLR")
# plt.plot(range(N_EPOCHS), E, label= "small-adaH")
# plt.plot(range(N_EPOCHS), F, label= "medium-adaH")
# plt.plot(range(N_EPOCHS), G, label= "wideM-adah")
# plt.plot(range(N_EPOCHS), H, label= "small-LALR")
# plt.plot(range(N_EPOCHS), I, label= "medium-LALR")
# plt.plot(range(N_EPOCHS), J, label= "wideM-LALR")

plt.yticks(np.arange(0.1, 0.25, 0.02))
plt.legend()

# %%
plt.plot(range(N_EPOCHS), loss_CLR, label= "small-CLR-loss")
# plt.plot(range(N_EPOCHS), loss_adaH, label= "small-adaH-loss")
plt.plot(range(N_EPOCHS), loss_LR, label= "small-LR-loss")
# plt.plot(range(N_EPOCHS), loss_CLR_MAE, label= "small-CLR-loss-MAE")
# plt.plot(range(N_EPOCHS), loss_LR_MAE, label= "small-LR-loss-MAE")

plt.legend()

# %%
# plt.plot(range(N_EPOCHS), val_CLR, label= "small-CLR-val")
# plt.plot(range(N_EPOCHS), val_adaH, label= "small-adaH-val")
# plt.plot(range(N_EPOCHS), val_LR, label= "small-LR-val")
plt.plot(range(N_EPOCHS), val_CLR_MAE, label= "small-CLR-val-MAE")
plt.plot(range(N_EPOCHS), val_LR_MAE, label= "small-LR-val-MAE")
plt.legend()
